# %% [markdown]
# ## Zenodo-Temperature

# %%
import pandas as pd

# %%
zenodo_temp = pd.read_excel('D:/Education/USA/SJSU/SEM 2/Analytical Processing DATA 270/Project/dataset/Final/Required_data/Zenodo_15-19_NY_PA.xlsx',
                            'Temp.')
zenodo_temp.head()
# Out:
#   OrganizationIdentifier                  OrganizationFormalName  \
# 0                USGS-NY      USGS New York Water Science Center
# 1                USGS-PA  USGS Pennsylvania Water Science Center
# 2                USGS-PA  USGS Pennsylvania Water Science Center
# 3                USGS-NY      USGS New York Water Science Center
# 4                USGS-PA  USGS Pennsylvania Water Science Center
#
#    ActivityIdentifier ActivityStartDate ActivityStartTime/Time  \
# 0  nwisny.01.01901025        2018-10-30               11:00:00
# 1  nwispa.01.01901538        2019-09-18               13:00:00
# 2  nwispa.01.01501196        2015-01-28               10:20:00
# 3  nwisny.01.01803719        2018-04-24               08:25:00
# 4  nwispa.01.01801151        2018-02-26               12:30:00
#
#   ActivityStartTime/TimeZoneCode MonitoringLocationIdentifier  \
# 0                            EST         USGS-411440074292901
# 1                            EDT                USGS-01444800
# ...

# %%
zenodo_temp[['CharacteristicName','ResultMeasure/MeasureUnitCode']].head()
# Out:
#    CharacteristicName ResultMeasure/MeasureUnitCode
# 0  Temperature, water                         deg C
# 1  Temperature, water                         deg C
# 2  Temperature, water                         deg C
# 3  Temperature, water                         deg C
# 4  Temperature, water                         deg C

# %%
zenodo_temp.columns
# Out:
# Index(['OrganizationIdentifier', 'OrganizationFormalName',
#        'ActivityIdentifier', 'ActivityStartDate', 'ActivityStartTime/Time',
#        'ActivityStartTime/TimeZoneCode', 'MonitoringLocationIdentifier',
#        'ResultIdentifier', 'DataLoggerLine', 'ResultDetectionConditionText',
#        'MethodSpecificationName', 'CharacteristicName',
#        'ResultSampleFractionText', 'ResultMeasureValue',
#        'ResultMeasure/MeasureUnitCode', 'MeasureQualifierCode',
#        'ResultStatusIdentifier', 'StatisticalBaseCode', 'ResultValueTypeName',
#        'ResultWeightBasisText', 'ResultTimeBasisText',
#        'ResultTemperatureBasisText', 'ResultParticleSizeBasisText',
#        'PrecisionValue', 'DataQuality/BiasValue', 'ConfidenceIntervalValue',
#        'UpperConfidenceLimitValue', 'LowerConfidenceLimitValue',
#        'ResultCommentText', 'USGSPCode',
#        'ResultDepthHeightMeasure/MeasureValue',
#        'ResultDepthHeightMeasure/MeasureUnitCode',
# ...

# %%
## dropping unnecessary columns

zenodo_temp = zenodo_temp[['ActivityStartDate','ActivityStartTime/Time','CharacteristicName',
                           'ResultMeasureValue','ResultMeasure/MeasureUnitCode']]
zenodo_temp.head()
# Out:
#   ActivityStartDate ActivityStartTime/Time  CharacteristicName  \
# 0        2018-10-30               11:00:00  Temperature, water
# 1        2019-09-18               13:00:00  Temperature, water
# 2        2015-01-28               10:20:00  Temperature, water
# 3        2018-04-24               08:25:00  Temperature, water
# 4        2018-02-26               12:30:00  Temperature, water
#
#    ResultMeasureValue ResultMeasure/MeasureUnitCode
# 0                 5.5                         deg C
# 1                20.7                         deg C
# 2                 0.0                         deg C
# 3                 5.2                         deg C
# 4                 3.8                         deg C

# %% [markdown]
# ## Zenodo-DO

# %%
zenodo_DO = pd.read_excel('D:/Education/USA/SJSU/SEM 2/Analytical Processing DATA 270/Project/dataset/Final/Required_data/Zenodo_15-19_NY_PA.xlsx',
                            'DO (mg-L)')
zenodo_DO.head()
# Out:
#   OrganizationIdentifier                  OrganizationFormalName  \
# 0                USGS-PA  USGS Pennsylvania Water Science Center
# 1                USGS-PA  USGS Pennsylvania Water Science Center
# 2                USGS-PA  USGS Pennsylvania Water Science Center
# 3                USGS-PA  USGS Pennsylvania Water Science Center
# 4                USGS-NY      USGS New York Water Science Center
#
#    ActivityIdentifier ActivityStartDate ActivityStartTime/Time  \
# 0  nwispa.01.01800403        2017-11-07               08:20:00
# 1  nwispa.01.01900809        2019-02-04               15:00:00
# 2  nwispa.01.01901136        2019-09-03               11:30:00
# 3  nwispa.01.01600035        2015-10-12               08:00:00
# 4  nwisny.01.01701989        2017-07-12               12:15:00
#
#   ActivityStartTime/TimeZoneCode MonitoringLocationIdentifier  \
# 0                            EST               USGS-015765195
# 1                            EST                USGS-03077500
# ...

# %%
zenodo_DO[['CharacteristicName','ResultSampleFractionText', 'ResultMeasure/MeasureUnitCode']].head()
# Out:
#   CharacteristicName ResultSampleFractionText ResultMeasure/MeasureUnitCode
# 0             Oxygen                Dissolved                          mg/l
# 1             Oxygen                Dissolved                          mg/l
# 2             Oxygen                Dissolved                          mg/l
# 3             Oxygen                Dissolved                          mg/l
# 4             Oxygen                Dissolved                          mg/l

# %%
## combining 'Dissolved' & 'Oxygen' under  CharacteristicName column 
zenodo_DO['CharacteristicName'] = zenodo_DO['ResultSampleFractionText'] + ' ' + zenodo_DO['CharacteristicName']  
zenodo_DO[['CharacteristicName']].head()
# Out:
#   CharacteristicName
# 0   Dissolved Oxygen
# 1   Dissolved Oxygen
# 2   Dissolved Oxygen
# 3   Dissolved Oxygen
# 4   Dissolved Oxygen

# %%
## dropping unnecessary columns

zenodo_DO = zenodo_DO[['ActivityStartDate','ActivityStartTime/Time','CharacteristicName',
                           'ResultMeasureValue','ResultMeasure/MeasureUnitCode']]
zenodo_DO.head()
# Out:
#   ActivityStartDate ActivityStartTime/Time CharacteristicName  \
# 0        2017-11-07               08:20:00   Dissolved Oxygen
# 1        2019-02-04               15:00:00   Dissolved Oxygen
# 2        2019-09-03               11:30:00   Dissolved Oxygen
# 3        2015-10-12               08:00:00   Dissolved Oxygen
# 4        2017-07-12               12:15:00   Dissolved Oxygen
#
#    ResultMeasureValue ResultMeasure/MeasureUnitCode
# 0                10.7                          mg/l
# 1                12.3                          mg/l
# 2                 9.2                          mg/l
# 3                11.2                          mg/l
# 4                 9.1                          mg/l

# %% [markdown]
# ## Zenodo-DO- Saturation

# %%
zenodo_DOS = pd.read_excel('D:/Education/USA/SJSU/SEM 2/Analytical Processing DATA 270/Project/dataset/Final/Required_data/Zenodo_15-19_NY_PA.xlsx',
                            'DO (%)')
zenodo_DOS.head()
# Out:
#   OrganizationIdentifier                  OrganizationFormalName  \
# 0                USGS-PA  USGS Pennsylvania Water Science Center
# 1                USGS-PA  USGS Pennsylvania Water Science Center
# 2                USGS-PA  USGS Pennsylvania Water Science Center
# 3                USGS-PA  USGS Pennsylvania Water Science Center
# 4                USGS-PA  USGS Pennsylvania Water Science Center
#
#    ActivityIdentifier ActivityStartDate ActivityStartTime/Time  \
# 0  nwispa.01.01800403        2017-11-07               08:20:00
# 1  nwispa.01.01900809        2019-02-04               15:00:00
# 2  nwispa.01.01600035        2015-10-12               08:00:00
# 3  nwispa.01.01900566        2019-03-14               10:30:00
# 4  nwispa.01.01801254        2018-02-22               09:30:00
#
#   ActivityStartTime/TimeZoneCode MonitoringLocationIdentifier  \
# 0                            EST               USGS-015765195
# 1                            EST                USGS-03077500
# ...

# %%
zenodo_DOS[['CharacteristicName','ResultSampleFractionText', 'ResultMeasure/MeasureUnitCode']].head()
# Out:
#   CharacteristicName ResultSampleFractionText ResultMeasure/MeasureUnitCode
# 0             Oxygen                Dissolved                    % saturatn
# 1             Oxygen                Dissolved                    % saturatn
# 2             Oxygen                Dissolved                    % saturatn
# 3             Oxygen                Dissolved                    % saturatn
# 4             Oxygen                Dissolved                    % saturatn

# %%
## combining 'Dissolved' & 'Oxygen' under  CharacteristicName column and adding 'Saturation' 
zenodo_DOS['CharacteristicName'] = zenodo_DOS['ResultSampleFractionText'] + ' ' + zenodo_DOS['CharacteristicName'] + ' ' + 'Saturation' 
zenodo_DOS['CharacteristicName'].head()
# Out:
# 0    Dissolved Oxygen Saturation
# 1    Dissolved Oxygen Saturation
# 2    Dissolved Oxygen Saturation
# 3    Dissolved Oxygen Saturation
# 4    Dissolved Oxygen Saturation
# Name: CharacteristicName, dtype: object

# %%
## dropping unnecessary columns

zenodo_DOS = zenodo_DOS[['ActivityStartDate','ActivityStartTime/Time','CharacteristicName',
                           'ResultMeasureValue','ResultMeasure/MeasureUnitCode']]
zenodo_DOS.head()
# Out:
#   ActivityStartDate ActivityStartTime/Time           CharacteristicName  \
# 0        2017-11-07               08:20:00  Dissolved Oxygen Saturation
# 1        2019-02-04               15:00:00  Dissolved Oxygen Saturation
# 2        2015-10-12               08:00:00  Dissolved Oxygen Saturation
# 3        2019-03-14               10:30:00  Dissolved Oxygen Saturation
# 4        2018-02-22               09:30:00  Dissolved Oxygen Saturation
#
#    ResultMeasureValue ResultMeasure/MeasureUnitCode
# 0                  95                    % saturatn
# 1                  91                    % saturatn
# 2                 103                    % saturatn
# 3                 105                    % saturatn
# 4                  99                    % saturatn

# %% [markdown]
# ## Zenodo-BOD

# %%
zenodo_BOD = pd.read_excel('D:/Education/USA/SJSU/SEM 2/Analytical Processing DATA 270/Project/dataset/Final/Required_data/Zenodo_15-19_NY_PA.xlsx',
                            'BOD')
zenodo_BOD.head()
# Out:
#   OrganizationIdentifier                  OrganizationFormalName  \
# 0                USGS-PA  USGS Pennsylvania Water Science Center
# 1                USGS-PA  USGS Pennsylvania Water Science Center
# 2                USGS-PA  USGS Pennsylvania Water Science Center
# 3                USGS-PA  USGS Pennsylvania Water Science Center
# 4                USGS-PA  USGS Pennsylvania Water Science Center
#
#    ActivityIdentifier ActivityStartDate ActivityStartTime/Time  \
# 0  nwispa.01.01601312        2016-03-28               13:30:00
# 1  nwispa.01.01801154        2018-02-27               14:00:00
# 2  nwispa.01.01501588        2015-05-11               11:00:00
# 3  nwispa.01.01701862        2017-06-21               14:30:00
# 4  nwispa.01.01901959        2019-08-07               11:00:00
#
#   ActivityStartTime/TimeZoneCode MonitoringLocationIdentifier  \
# 0                            EDT                USGS-01550000
# 1                            EST                USGS-01431600
# ...

# %%
zenodo_BOD[['CharacteristicName', 'ResultMeasure/MeasureUnitCode']].head()
# Out:
#                                CharacteristicName  \
# 0  Biochemical oxygen demand, standard conditions
# 1  Biochemical oxygen demand, standard conditions
# 2  Biochemical oxygen demand, standard conditions
# 3  Biochemical oxygen demand, standard conditions
# 4  Biochemical oxygen demand, standard conditions
#
#   ResultMeasure/MeasureUnitCode
# 0                          mg/l
# 1                          mg/l
# 2                          mg/l
# 3                          mg/l
# 4                          mg/l

# %%
## dropping unnecessary columns
zenodo_BOD = zenodo_BOD[['ActivityStartDate','ActivityStartTime/Time','CharacteristicName',
                           'ResultMeasureValue','ResultMeasure/MeasureUnitCode']]
zenodo_BOD.head()
# Out:
#   ActivityStartDate ActivityStartTime/Time  \
# 0        2016-03-28               13:30:00
# 1        2018-02-27               14:00:00
# 2        2015-05-11               11:00:00
# 3        2017-06-21               14:30:00
# 4        2019-08-07               11:00:00
#
#                                CharacteristicName  ResultMeasureValue  \
# 0  Biochemical oxygen demand, standard conditions                 1.0
# 1  Biochemical oxygen demand, standard conditions                 1.2
# 2  Biochemical oxygen demand, standard conditions                 0.9
# 3  Biochemical oxygen demand, standard conditions                 0.8
# 4  Biochemical oxygen demand, standard conditions                 0.3
#
#   ResultMeasure/MeasureUnitCode
# 0                          mg/l
# 1                          mg/l
# 2                          mg/l
# 3                          mg/l
# 4                          mg/l

# %% [markdown]
# ## Zenodo-P

# %%
zenodo_P = pd.read_excel('D:/Education/USA/SJSU/SEM 2/Analytical Processing DATA 270/Project/dataset/Final/Required_data/Zenodo_15-19_NY_PA.xlsx',
                            'Phosphorus')
zenodo_P.head()
# Out:
#   OrganizationIdentifier                  OrganizationFormalName  \
# 0                USGS-PA  USGS Pennsylvania Water Science Center
# 1                USGS-PA  USGS Pennsylvania Water Science Center
# 2                USGS-NY      USGS New York Water Science Center
# 3                USGS-PA  USGS Pennsylvania Water Science Center
# 4                USGS-PA  USGS Pennsylvania Water Science Center
#
#    ActivityIdentifier ActivityStartDate ActivityStartTime/Time  \
# 0  nwispa.01.01800403        2017-11-07               08:20:00
# 1  nwispa.01.01900809        2019-02-04               15:00:00
# 2  nwisny.01.01701989        2017-07-12               12:15:00
# 3  nwispa.01.01900566        2019-03-14               10:30:00
# 4  nwispa.01.01801254        2018-02-22               09:30:00
#
#   ActivityStartTime/TimeZoneCode MonitoringLocationIdentifier  \
# 0                            EST               USGS-015765195
# 1                            EST                USGS-03077500
# ...

# %%
zenodo_P[['CharacteristicName', 'ResultMeasure/MeasureUnitCode']].head()
# Out:
#   CharacteristicName ResultMeasure/MeasureUnitCode
# 0         Phosphorus                     mg/l as P
# 1         Phosphorus                     mg/l as P
# 2         Phosphorus                     mg/l as P
# 3         Phosphorus                     mg/l as P
# 4         Phosphorus                     mg/l as P

# %%
## dropping unnecessary columns
zenodo_P = zenodo_P[['ActivityStartDate','ActivityStartTime/Time','CharacteristicName',
                           'ResultMeasureValue','ResultMeasure/MeasureUnitCode']]
zenodo_P.head()
# Out:
#   ActivityStartDate ActivityStartTime/Time CharacteristicName  \
# 0        2017-11-07               08:20:00         Phosphorus
# 1        2019-02-04               15:00:00         Phosphorus
# 2        2017-07-12               12:15:00         Phosphorus
# 3        2019-03-14               10:30:00         Phosphorus
# 4        2018-02-22               09:30:00         Phosphorus
#
#    ResultMeasureValue ResultMeasure/MeasureUnitCode
# 0               0.030                     mg/l as P
# 1               0.010                     mg/l as P
# 2               0.014                     mg/l as P
# 3               0.050                     mg/l as P
# 4               0.020                     mg/l as P

# %% [markdown]
# ## Stacking the parameter datasets

# %%
zenodo_stack_1 = pd.concat([zenodo_temp, zenodo_DO, zenodo_DOS, zenodo_BOD, zenodo_P])
zenodo_stack_1
# Out:
#      ActivityStartDate ActivityStartTime/Time  CharacteristicName  \
# 0           2018-10-30               11:00:00  Temperature, water
# 1           2019-09-18               13:00:00  Temperature, water
# 2           2015-01-28               10:20:00  Temperature, water
# 3           2018-04-24               08:25:00  Temperature, water
# 4           2018-02-26               12:30:00  Temperature, water
# ...                ...                    ...                 ...
# 9456        2016-10-31               07:45:00          Phosphorus
# 9457        2017-02-08               23:06:00          Phosphorus
# 9458        2018-08-14               12:37:00          Phosphorus
# 9459        2019-10-31               17:50:00          Phosphorus
# 9460        2017-05-07               07:50:00          Phosphorus
#
#       ResultMeasureValue ResultMeasure/MeasureUnitCode
# 0                  5.500                         deg C
# 1                 20.700                         deg C
# ...

# %%
## sushmita parameters - NH3, N, NO, SSC
zenodo_stack_2 = pd.read_excel('D:/Education/USA/SJSU/SEM 2/Analytical Processing DATA 270/Project/dataset/Final/Required_data/Zenodo_NH3_N_NO_SSC.xlsx',
                               'Sheet1')
zenodo_stack_2.drop(columns='Unnamed: 0', inplace=True)
zenodo_stack_2.head()
# Out:
#   ActivityStartDate ActivityStartTime/Time    CharacteristicName  \
# 0        2017-11-07               08:20:00  Ammonia and ammonium
# 1        2016-01-06               14:00:00  Ammonia and ammonium
# 2        2019-02-04               15:00:00  Ammonia and ammonium
# 3        2019-03-06               09:10:00  Ammonia and ammonium
# 4        2016-05-28               01:30:00  Ammonia and ammonium
#
#    ResultMeasureValue ResultMeasure/MeasureUnitCode
# 0                 NaN                           NaN
# 1                0.09                     mg/l as N
# 2                0.03                     mg/l as N
# 3                 NaN                           NaN
# 4                2.08                     mg/l as N

# %%
## madhura parameters - pH, TSS, N-total
zenodo_stack_3 = pd.read_csv('D:/Education/USA/SJSU/SEM 2/Analytical Processing DATA 270/Project/dataset/Final/Required_data/zenodo_pH_TSS_N-total.csv',)
zenodo_stack_3.drop(columns='Unnamed: 0', inplace=True)
zenodo_stack_3.head()
# Out:
#   ActivityStartDate ActivityStartTime/Time CharacteristicName  \
# 0         11/7/2017                8:20:00                 pH
# 1          2/4/2019               15:00:00                 pH
# 2          9/3/2019               11:30:00                 pH
# 3        10/12/2015                8:00:00                 pH
# 4         7/12/2017               12:15:00                 pH
#
#    ResultMeasureValue ResultMeasure/MeasureUnitCode
# 0                 7.8                     std units
# 1                 7.8                     std units
# 2                 7.9                     std units
# 3                 7.5                     std units
# 4                 8.3                     std units

# %%
## Final Zenodo Dataset with all parameters

# %%
zenodo = pd.concat([zenodo_stack_1, zenodo_stack_2, zenodo_stack_3])
zenodo
# Out:
#          ActivityStartDate ActivityStartTime/Time  \
# 0      2018-10-30 00:00:00               11:00:00
# 1      2019-09-18 00:00:00               13:00:00
# 2      2015-01-28 00:00:00               10:20:00
# 3      2018-04-24 00:00:00               08:25:00
# 4      2018-02-26 00:00:00               12:30:00
# ...                    ...                    ...
# 21389             4/9/2018               13:45:00
# 21390             2/8/2017               23:06:00
# 21391            8/14/2018               12:37:00
# 21392           10/31/2019               17:50:00
# 21393             5/7/2017                7:50:00
#
#                                       CharacteristicName  ResultMeasureValue  \
# 0                                     Temperature, water                 5.5
# 1                                     Temperature, water                20.7
# 2                                     Temperature, water                 0.0
# ...

# %%
## convert to excel file
zenodo.to_excel('Zenodo_DRB.xlsx', index=False)
